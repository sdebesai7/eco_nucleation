# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('N_v_t.pkl', 'rb') as f:
    N_v_t=pkl.load(f)
f.close()

with open('A_matrix.pkl', 'rb') as f:
   A=pkl.load(f)
f.close()

with open('times.pkl', 'rb') as f:
    T=pkl.load(f)
f.close()

with open('rates.pkl', 'rb') as f:
    rates=pkl.load(f)
f.close()

# %%
print(A)
print(rates)
# Out:
# [[ 1.          0.45273137  0.06081213]
#  [ 0.84632634  1.          0.01879412]
#  [ 0.98017305 -0.39305985  1.        ]]
# [-0.07570495 -0.35679033 -0.31557537]

# %%
fig, ax=plt.subplots(1)

for i, col in enumerate(N_v_t.T):
    ax.plot(T[:-1], col, label=f'species {i}')

ax.set_xlabel('t')
ax.set_ylabel('N')
ax.legend(bbox_to_anchor=[1, 1.05], loc='upper left')
